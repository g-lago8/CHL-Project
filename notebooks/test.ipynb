# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('..\\datasets\\aku_prin_v2.0.xlsx')
# Out:
#     patient sex   birth  creatinine_urines mg/dl  HGA_u mg/dl HGA_U mg/24h  \
# 0      101A   F  1963.0                    24.88   111.360000          NaN
# 1      102A   F  1964.0                    26.01    89.220390          NaN
# 2      105A   F  1958.0                    32.80   156.127275          NaN
# 3      106A   F  1954.0                    18.09    68.134380          NaN
# 4      107A   F  1952.0                    36.19   165.291450          NaN
# ..      ...  ..     ...                      ...          ...          ...
# 214    296C   M  2014.0                    17.96   264.740000        42.26
# 215    297C   M  1995.0                   267.62   709.960000       709.96
# 216    298C   M  1965.0                    96.89   287.680000      6904.25
# 217    298S   M  1965.0                      NaN          NaN          NaN
# 218    299S   M  1952.0                      NaN          NaN          NaN
#
# ...

# %%
df
# Out:
#     patient sex   birth  creatinine_urines mg/dl  HGA_u mg/dl HGA_U mg/24h  \
# 0      101A   F  1963.0                    24.88   111.360000          NaN
# 1      102A   F  1964.0                    26.01    89.220390          NaN
# 2      105A   F  1958.0                    32.80   156.127275          NaN
# 3      106A   F  1954.0                    18.09    68.134380          NaN
# 4      107A   F  1952.0                    36.19   165.291450          NaN
# ..      ...  ..     ...                      ...          ...          ...
# 214    296C   M  2014.0                    17.96   264.740000        42.26
# 215    297C   M  1995.0                   267.62   709.960000       709.96
# 216    298C   M  1965.0                    96.89   287.680000      6904.25
# 217    298S   M  1965.0                      NaN          NaN          NaN
# 218    299S   M  1952.0                      NaN          NaN          NaN
#
# ...

# %%
df.describe()
# Out:
#              birth  creatinine_urines mg/dl  HGA_u mg/dl         bqa  \
# count   213.000000                78.000000    89.000000    6.000000
# mean   1965.122066               121.869538   232.385753   55.908333
# std      13.770153               326.520185   269.182330   65.174104
# min    1934.000000                17.960000     0.521265   16.700000
# 25%    1955.000000                47.510400    22.918845   20.070000
# 50%    1963.000000                69.003200   187.350000   30.600000
# 75%    1973.000000               102.552000   281.320000   48.892500
# max    2014.000000              2920.590000  1322.330000  186.000000
#
#           urate  uric_acid_urine  hypoxanthine_urines  xanthine_urines  \
# count  2.000000        30.000000              5.00000         6.000000
# mean   2.345000        72.471000              1.64600         3.306667
# std    0.205061        64.125895              1.24785         3.214048
# ...
