# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('../datasets/aku_prin_v2.0.xlsx')

# %%
df.head()
# Out:
#   patient sex   birth  creatinine_urines mg/dl  HGA_u mg/dl HGA_U mg/24h  bqa  \
# 0    101A   F  1963.0                    24.88   111.360000          NaN  NaN
# 1    102A   F  1964.0                    26.01    89.220390          NaN  NaN
# 2    105A   F  1958.0                    32.80   156.127275          NaN  NaN
# 3    106A   F  1954.0                    18.09    68.134380          NaN  NaN
# 4    107A   F  1952.0                    36.19   165.291450          NaN  NaN
#
#    urate  uric_acid_urine tyr_urines  ...  creatinine_plasma  hga_plasma tyr  \
# 0    NaN              NaN       0.51  ...                NaN         NaN NaN
# 1    NaN              NaN   0.652284  ...                NaN         NaN NaN
# 2    NaN              NaN    1.08714  ...                NaN         NaN NaN
# 3    NaN              NaN      <0.35  ...                NaN         NaN NaN
# 4    NaN              NaN      <0.35  ...                NaN         NaN NaN
#
# ...

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\Giamm\AppData\Local\Temp\ipykernel_9644\3247852998.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %%
df2=df.loc[:,pd.isnull(df).sum()<=100]

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df2.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\Giamm\AppData\Local\Temp\ipykernel_9644\154335809.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(), annot=True, cmap='coolwarm')

# %%
df2.columns
# Out:
# Index(['patient', 'sex', 'birth', 'Protein change allele 1 ',
#        'DNA change allele 1', 'Exon/intron allele 1',
#        'Protein change allele 2', 'DNA change allele 2', 'ex/in allele 2',
#        'SAA (ug/mL) ', 'chitotriosidase', 'aopp', 'bmi',
#        'physical_health_score', 'mental_health_score', 'AKUSSI_jointpain',
#        'AKUSSI_spinalpain', 'KOOSpain', 'KOOSsymptoms', 'KOOSdaily_living',
#        'KOOSsport', 'KOOS_QOL', 'HAQ_hapVAS', 'HAQ_haqDI'],
#       dtype='object')

# %%
df2=df2[['physical_health_score', 'mental_health_score', 'AKUSSI_jointpain',
        'AKUSSI_spinalpain', 'KOOSpain', 'KOOSsymptoms', 'KOOSdaily_living',
        'KOOSsport', 'KOOS_QOL', 'HAQ_hapVAS', 'HAQ_haqDI']]

# %%
df2
# Out:
#      physical_health_score  mental_health_score  AKUSSI_jointpain  \
# 0                     26.0                 43.0              57.0
# 1                     53.0                 51.0              29.0
# 2                     23.0                 40.0              36.0
# 3                      NaN                  NaN               NaN
# 4                     23.0                 29.0              50.0
# ..                     ...                  ...               ...
# 214                    NaN                  NaN               NaN
# 215                    NaN                  NaN               NaN
# 216                    NaN                  NaN               NaN
# 217                   31.0                 51.0              43.0
# 218                   26.0                 61.0              29.0
#
#      AKUSSI_spinalpain  KOOSpain  KOOSsymptoms  KOOSdaily_living  KOOSsport  \
# 0                 75.0      67.0          89.0              75.0       70.0
# ...

# %%
df2=df2.join(df[['Protein change allele 1 ','Protein change allele 2']])

# %%
df2
# Out:
#      physical_health_score  mental_health_score  AKUSSI_jointpain  \
# 0                     26.0                 43.0              57.0
# 1                     53.0                 51.0              29.0
# 2                     23.0                 40.0              36.0
# 3                      NaN                  NaN               NaN
# 4                     23.0                 29.0              50.0
# ..                     ...                  ...               ...
# 214                    NaN                  NaN               NaN
# 215                    NaN                  NaN               NaN
# 216                    NaN                  NaN               NaN
# 217                   31.0                 51.0              43.0
# 218                   26.0                 61.0              29.0
#
#      AKUSSI_spinalpain  KOOSpain  KOOSsymptoms  KOOSdaily_living  KOOSsport  \
# 0                 75.0      67.0          89.0              75.0       70.0
# ...

# %%
mutation_set={'G161R', 'M368V', 'A122V', 'E401Q', 'D153fs'}
df2=df2.loc[df2['Protein change allele 1 '].isin(mutation_set) | df2['Protein change allele 2'].isin(mutation_set)]

# %%
df2
# Out:
#      physical_health_score  mental_health_score  AKUSSI_jointpain  \
# 0                     26.0                 43.0              57.0
# 1                     53.0                 51.0              29.0
# 2                     23.0                 40.0              36.0
# 4                     23.0                 29.0              50.0
# 5                     26.0                 31.0              50.0
# ..                     ...                  ...               ...
# 205                   49.0                 49.0               NaN
# 206                    NaN                  NaN               NaN
# 209                    NaN                  NaN               NaN
# 210                    NaN                  NaN               NaN
# 215                    NaN                  NaN               NaN
#
#      AKUSSI_spinalpain  KOOSpain  KOOSsymptoms  KOOSdaily_living  KOOSsport  \
# 0                 75.0      67.0          89.0              75.0       70.0
# ...

# %%
df2=df2.dropna(axis=0)

# %%
df2
# Out:
#      physical_health_score  mental_health_score  AKUSSI_jointpain  \
# 0                     26.0                 43.0              57.0
# 1                     53.0                 51.0              29.0
# 2                     23.0                 40.0              36.0
# 4                     23.0                 29.0              50.0
# 5                     26.0                 31.0              50.0
# ..                     ...                  ...               ...
# 186                   43.0                 56.0               7.0
# 187                   37.0                 54.0              29.0
# 188                   30.0                 39.0              29.0
# 189                   40.0                 50.0              21.0
# 190                   33.0                 31.0              43.0
#
#      AKUSSI_spinalpain  KOOSpain  KOOSsymptoms  KOOSdaily_living  KOOSsport  \
# 0                 75.0      67.0          89.0              75.0       70.0
# ...

# %%
df2['AKUSSI_jointpain'][190]
# Out:
# 43.0

# %%
labels=df2[['Protein change allele 1 ','Protein change allele 2']]

# %%
df2=df2.drop(columns=['Protein change allele 1 ','Protein change allele 2'])

# %%
df2
# Out:
#      physical_health_score  mental_health_score  AKUSSI_jointpain  \
# 0                     26.0                 43.0              57.0
# 1                     53.0                 51.0              29.0
# 2                     23.0                 40.0              36.0
# 4                     23.0                 29.0              50.0
# 5                     26.0                 31.0              50.0
# ..                     ...                  ...               ...
# 186                   43.0                 56.0               7.0
# 187                   37.0                 54.0              29.0
# 188                   30.0                 39.0              29.0
# 189                   40.0                 50.0              21.0
# 190                   33.0                 31.0              43.0
#
#      AKUSSI_spinalpain  KOOSpain  KOOSsymptoms  KOOSdaily_living  KOOSsport  \
# 0                 75.0      67.0          89.0              75.0       70.0
# ...

# %%
df2.isnull().sum()
# Out:
# physical_health_score    0
# mental_health_score      0
# AKUSSI_jointpain         0
# AKUSSI_spinalpain        0
# KOOSpain                 0
# KOOSsymptoms             0
# KOOSdaily_living         0
# KOOSsport                0
# KOOS_QOL                 0
# HAQ_hapVAS               0
# HAQ_haqDI                0
# dtype: int64

# %% [markdown]
# # Clustering

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, FastICA
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# %%
scaler = StandardScaler()
df2_scaled = scaler.fit_transform(df2)
df2_scaled = pd.DataFrame(df2_scaled, columns=df2.columns)
df2_scaled.describe()
# Out:
#        physical_health_score  mental_health_score  AKUSSI_jointpain  \
# count           7.400000e+01         7.400000e+01      7.400000e+01
# mean           -2.543011e-16        -1.800362e-17      9.001808e-17
# std             1.006826e+00         1.006826e+00      1.006826e+00
# min            -2.103794e+00        -1.743144e+00     -1.433047e+00
# 25%            -7.652689e-01        -8.492240e-01     -8.147059e-01
# 50%            -4.452474e-02         1.787840e-01     -1.521978e-01
# 75%             6.504786e-01         6.704400e-01      4.661431e-01
# max             2.220671e+00         1.832536e+00      2.674503e+00
#
#        AKUSSI_spinalpain      KOOSpain  KOOSsymptoms  KOOSdaily_living  \
# count       7.400000e+01  7.400000e+01  7.400000e+01      7.400000e+01
# mean       -6.601326e-17  2.618026e-16  3.900784e-17      2.618026e-16
# std         1.006826e+00  1.006826e+00  1.006826e+00      1.006826e+00
# ...

# %%
kmeans = []

SSE = []

silhouette_scores = []

for i in range(1, 11):
    kmeans.append( 
        KMeans(
            n_clusters=i, 
            random_state=0, 
            n_init=1
        ).fit(df2_scaled) 
    )
    
    SSE.append(kmeans[i-1].inertia_)
    
    if i > 1:
        silhouette_scores.append(
            silhouette_score(
                df2_scaled, 
                kmeans[i-1].labels_, 
                metric='euclidean',
                sample_size=74
            )
        )

# %%
plt.plot( range(1,11),SSE, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
# change numbers on x axis
plt.xticks(np.arange(1, 11, step=1))
plt.show()

# %%
# We plot the silhouette scores in another plot since the scale is different than the SSE
plt.plot( range(2,11), silhouette_scores, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette score')
# change numbers on x axis
plt.xticks(np.arange(2, 11, step=1))
plt.show()

# %%
# We choose k = 3 clusters
kmeans = KMeans(n_clusters=3, random_state=0, n_init=10).fit(df2_scaled)
labels['cluster_kmeans'] = kmeans.labels_
# Out:
# C:\Users\Giamm\AppData\Local\Temp\ipykernel_9644\2027748506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labels['cluster_kmeans'] = kmeans.labels_

# %%
df2['cluster_kmeans'] = kmeans.labels_

# %%
labels['Protein change allele 1 '].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Protein change allele 1 '>

# %%
labels['Protein change allele 2'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Protein change allele 2'>

# %%
#pca in order to reduce the dimensionality of the dataset
pca = PCA(n_components=2)
df2_pca = pca.fit_transform(df2_scaled)
# plot of the results
plt.scatter(df2_pca[:,0], df2_pca[:,1], s=10)

# %%
# We report the clusters on the PCA plot
plt.scatter(df2_pca[:,0], df2_pca[:,1], c=labels['cluster_kmeans'], s=10, cmap='plasma')

# %%
sns.countplot(data=df2, x='cluster_kmeans', hue=labels['Protein change allele 1 '])
# Out:
# <Axes: xlabel='cluster_kmeans', ylabel='count'>

# %%
sns.countplot(data=df2, x='cluster_kmeans', hue=labels['Protein change allele 2'])
# Out:
# <Axes: xlabel='cluster_kmeans', ylabel='count'>
